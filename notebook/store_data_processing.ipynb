# %%
import pandas as pd
store= pd.read_csv(r'C:\Users\Yibabe\Desktop\10academyAIMweek-4\data\store.csv')

# %%
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
store.describe()
# Out:
#             Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# count  1115.00000          1112.000000                 761.000000
# mean    558.00000          5404.901079                   7.224704
# std     322.01708          7663.174720                   3.212348
# min       1.00000            20.000000                   1.000000
# 25%     279.50000           717.500000                   4.000000
# 50%     558.00000          2325.000000                   8.000000
# 75%     836.50000          6882.500000                  10.000000
# max    1115.00000         75860.000000                  12.000000
#
#        CompetitionOpenSinceYear       Promo2  Promo2SinceWeek  Promo2SinceYear
# count                761.000000  1115.000000       571.000000       571.000000
# mean                2008.668857     0.512108        23.595447      2011.763573
# std                    6.195983     0.500078        14.141984         1.674935
# ...

# %%
store.shape
# Out:
# (1115, 10)

# %%
store.columns
# Out:
# Index(['Store', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
store.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
# Handling CompetitionDistance (impute with 0)
store['CompetitionDistance'].fillna(0, inplace=True)

# Handling CompetitionOpenSinceMonth and CompetitionOpenSinceYear (impute with median)
store['CompetitionOpenSinceMonth'].fillna(store['CompetitionOpenSinceMonth'].median(), inplace=True)
store['CompetitionOpenSinceYear'].fillna(store['CompetitionOpenSinceYear'].median(), inplace=True)

# Handling Promo2SinceWeek and Promo2SinceYear (impute with median)
store['Promo2SinceWeek'].fillna(store['Promo2SinceWeek'].median(), inplace=True)
store['Promo2SinceYear'].fillna(store['Promo2SinceYear'].median(), inplace=True)

# Handling PromoInterval (impute with a placeholder)
store['PromoInterval'].fillna('NoPromo', inplace=True)
# Out:
# C:\Users\Yibabe\AppData\Local\Temp\ipykernel_10148\1732732546.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   store['CompetitionDistance'].fillna(0, inplace=True)
# C:\Users\Yibabe\AppData\Local\Temp\ipykernel_10148\1732732546.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
store_cleaned = store

# %%
store_cleaned.head(20)
# Out:
#     Store StoreType Assortment  CompetitionDistance  \
# 0       1         c          a               1270.0
# 1       2         a          a                570.0
# 2       3         a          a              14130.0
# 3       4         c          c                620.0
# 4       5         a          a              29910.0
# 5       6         a          a                310.0
# 6       7         a          c              24000.0
# 7       8         a          a               7520.0
# 8       9         a          c               2030.0
# 9      10         a          a               3160.0
# 10     11         a          c                960.0
# 11     12         a          c               1070.0
# 12     13         d          a                310.0
# 13     14         a          a               1300.0
# 14     15         d          c               4110.0
# 15     16         a          c               3270.0
# 16     17         a          a                 50.0
# ...

# %%
store_cleaned.describe()
# Out:
#             Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# count  1115.00000          1115.000000                1115.000000
# mean    558.00000          5390.358744                   7.470852
# std     322.01708          7657.973705                   2.677756
# min       1.00000             0.000000                   1.000000
# 25%     279.50000           710.000000                   6.000000
# 50%     558.00000          2320.000000                   8.000000
# 75%     836.50000          6875.000000                   9.000000
# max    1115.00000         75860.000000                  12.000000
#
#        CompetitionOpenSinceYear       Promo2  Promo2SinceWeek  Promo2SinceYear
# count               1115.000000  1115.000000      1115.000000      1115.000000
# mean                2009.091480     0.512108        22.817040      2011.878924
# std                    5.155105     0.500078        10.147329         1.203919
# ...

# %%
#upload the test file and clean it
test= pd.read_csv(r'C:\Users\Yibabe\Desktop\10academyAIMweek-4\data\test.csv')

# %%
test.head(20)
# Out:
#     Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0    1      1          4  2015-09-17   1.0      1            0              0
# 1    2      3          4  2015-09-17   1.0      1            0              0
# 2    3      7          4  2015-09-17   1.0      1            0              0
# 3    4      8          4  2015-09-17   1.0      1            0              0
# 4    5      9          4  2015-09-17   1.0      1            0              0
# 5    6     10          4  2015-09-17   1.0      1            0              0
# 6    7     11          4  2015-09-17   1.0      1            0              0
# 7    8     12          4  2015-09-17   1.0      1            0              0
# 8    9     13          4  2015-09-17   1.0      1            0              0
# 9   10     14          4  2015-09-17   1.0      1            0              0
# 10  11     15          4  2015-09-17   1.0      1            0              0
# ...

# %%
test.shape
# Out:
# (41088, 8)

# %%
test.isnull().sum()
# Out:
# Id                0
# Store             0
# DayOfWeek         0
# Date              0
# Open             11
# Promo             0
# StateHoliday      0
# SchoolHoliday     0
# dtype: int64

# %%
as we have seen from the above only the columns 'open' have null value so we fill with the median

# %%
test['Open'].fillna(test['Open'].median(), inplace=True)
# Out:
# C:\Users\Yibabe\AppData\Local\Temp\ipykernel_10148\1919502812.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test['Open'].fillna(test['Open'].median(), inplace=True)

# %%
test.isnull().sum()
# Out:
# Id               0
# Store            0
# DayOfWeek        0
# Date             0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
test.describe()
# Out:
#                  Id         Store     DayOfWeek          Open         Promo  \
# count  41088.000000  41088.000000  41088.000000  41088.000000  41088.000000
# mean   20544.500000    555.899533      3.979167      0.854361      0.395833
# std    11861.228267    320.274496      2.015481      0.352748      0.489035
# min        1.000000      1.000000      1.000000      0.000000      0.000000
# 25%    10272.750000    279.750000      2.000000      1.000000      0.000000
# 50%    20544.500000    553.500000      4.000000      1.000000      0.000000
# 75%    30816.250000    832.250000      6.000000      1.000000      1.000000
# max    41088.000000   1115.000000      7.000000      1.000000      1.000000
#
#        SchoolHoliday
# count   41088.000000
# mean        0.443487
# std         0.496802
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %%
load the train file and clean if like the test and store file

# %%
#upload the train file and clean it
train= pd.read_csv(r'C:\Users\Yibabe\Desktop\10academyAIMweek-4\data\train.csv')
# Out:
# C:\Users\Yibabe\AppData\Local\Temp\ipykernel_10148\2697311463.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train= pd.read_csv(r'C:\Users\Yibabe\Desktop\10academyAIMweek-4\data\train.csv')

# %%
train.shape
# Out:
# (1017209, 9)

# %%
train.head(100000)
# Out:
#        Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0          1          5  2015-07-31   5263        555     1      1
# 1          2          5  2015-07-31   6064        625     1      1
# 2          3          5  2015-07-31   8314        821     1      1
# 3          4          5  2015-07-31  13995       1498     1      1
# 4          5          5  2015-07-31   4822        559     1      1
# ...      ...        ...         ...    ...        ...   ...    ...
# 99995    761          7  2015-05-03      0          0     0      0
# 99996    762          7  2015-05-03      0          0     0      0
# 99997    763          7  2015-05-03      0          0     0      0
# 99998    764          7  2015-05-03      0          0     0      0
# 99999    765          7  2015-05-03      0          0     0      0
#
#       StateHoliday  SchoolHoliday
# 0                0              1
# 1                0              1
# 2                0              1
# ...

# %%
train.isnull().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
train.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Id', 'Store', 'DayOfWeek', 'Date', 'Open', 'Promo', 'StateHoliday',
#        'SchoolHoliday'],
#       dtype='object')

# %%
store.columns
# Out:
# Index(['Store', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
# Merge train data with store data
train_merged = pd.merge(train, store_cleaned, how='left', on='Store')

# %%
train_merged.head(2000)
# Out:
#       Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0         1          5  2015-07-31   5263        555     1      1
# 1         2          5  2015-07-31   6064        625     1      1
# 2         3          5  2015-07-31   8314        821     1      1
# 3         4          5  2015-07-31  13995       1498     1      1
# 4         5          5  2015-07-31   4822        559     1      1
# ...     ...        ...         ...    ...        ...   ...    ...
# 1995    881          4  2015-07-30   5571        625     1      1
# 1996    882          4  2015-07-30   6491        763     1      1
# 1997    883          4  2015-07-30   4643        458     1      1
# 1998    884          4  2015-07-30   7000        608     1      1
# 1999    885          4  2015-07-30   5942        722     1      1
#
#      StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0               0              1         c          a               1270.0
# ...

# %%
train_merged.shape
# Out:
# (1017209, 18)

# %%
train_merged.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import make_column_selector as selector

# %%
train_merged.isnull().sum()
# Out:
# Store                        0
# DayOfWeek                    0
# Date                         0
# Sales                        0
# Customers                    0
# Open                         0
# Promo                        0
# StateHoliday                 0
# SchoolHoliday                0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# dtype: int64

# %%
train_merged['Date'] = pd.to_datetime(train_merged['Date'])  # Convert 'Date' to datetime

# %%
train_merged.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         a          a                570.0
# 2              1         a          a              14130.0
# 3              1         c          c                620.0
# 4              1         a          a              29910.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# ...

# %%
Univariate Analysis
Distribution of Target Variable ('Sales')
Use histograms or box plots to visualize the distribution.
Check for outliers.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(train_merged['Sales'], bins=30, kde=True)
plt.title('Distribution of Sales')
plt.show()

# %%
Categorical Variables
Visualize the frequency of each category using bar plots for columns like 'StoreType', 'Assortment', and 'DayOfWeek'.

# %%
sns.countplot(x='StoreType', data=train_merged)
plt.title('Store Type Distribution')
plt.show()

# %%
 Bivariate Analysis
Sales vs. Other Variables
Plot how 'Sales' relate to other features like 'Promo', 'StateHoliday', and 'DayOfWeek'.

# %%
sns.boxplot(x='Promo', y='Sales', data=train_merged)
plt.title('Sales Distribution by Promo')
plt.show()

# %%
Sales by Store Type and Assortment
Compare 'Sales' across different 'StoreType' and 'Assortment' categories.

# %%
sns.boxplot(x='StoreType', y='Sales', data=train_merged)
plt.title('Sales by Store Type')
plt.show()

# %%
Sales Over Time
Plot the 'Sales' trend over time, especially focusing on patterns across different months, weekdays, or holiday seasons.

# %%
train_merged['Month'] = train_merged['Date'].dt.month
train_merged['Year'] = train_merged['Date'].dt.year

sales_by_month = train_merged.groupby('Month')['Sales'].sum()
sales_by_month.plot(kind='bar')
plt.title('Total Sales by Month')
plt.show()

# %%
sns.pairplot(train_merged, vars=['Sales', 'Customers', 'CompetitionDistance'])
plt.show()

# %%
Using IQR (Interquartile Range)
The IQR method is more robust to skewed data. This method calculates the range between the 25th and 75th percentiles and removes points that fall beyond 1.5 times the IQR.

# %%
cols = ['Sales', 'Customers', 'CompetitionDistance']

# %%
Q1 = train_merged[cols].quantile(0.25)
Q3 = train_merged[cols].quantile(0.75)
IQR = Q3 - Q1

# Filter out points beyond 1.5*IQR
df_cleaned = train_merged[~((train_merged[cols] < (Q1 - 1.5 * IQR)) | (train_merged[cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df_cleaned['CompetitionOpenTime'] = (df_cleaned['Year'] - df_cleaned['CompetitionOpenSinceYear'])*12 + (df_cleaned['Month'] - df_cleaned['CompetitionOpenSinceMonth'])
# Out:
# C:\Users\Yibabe\AppData\Local\Temp\ipykernel_10148\1913727606.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['CompetitionOpenTime'] = (df_cleaned['Year'] - df_cleaned['CompetitionOpenSinceYear'])*12 + (df_cleaned['Month'] - df_cleaned['CompetitionOpenSinceMonth'])

# %%
df_cleaned.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 5      6          5 2015-07-31   5651        589     1      1            0
# 7      8          5 2015-07-31   8492        833     1      1            0
#
#    SchoolHoliday StoreType  ... CompetitionDistance  \
# 0              1         c  ...              1270.0
# 1              1         a  ...               570.0
# 2              1         a  ...             14130.0
# 5              1         a  ...               310.0
# 7              1         a  ...              7520.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                       11.0                    2007.0       1
# ...

# %%
sns.pairplot(df_cleaned, vars=['Sales', 'Customers', 'CompetitionDistance'])
plt.show()

# %%
df_cleaned['Date'] = pd.to_datetime(df_cleaned['Date'])
# Out:
# C:\Users\Yibabe\AppData\Local\Temp\ipykernel_10148\378315545.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Date'] = pd.to_datetime(df_cleaned['Date'])

# %%
Identify Holiday Periods The column StateHoliday should indicate whether a date is during a public holiday. You might also want to create new columns that indicate whether a date is before or after a holiday.

Before Holiday: Create a column to identify days just before holidays (e.g., the day before a holiday).
During Holiday: Use the StateHoliday column.
After Holiday: Create a column to identify days immediately following holidays.

# %%
# Mark days as 'Before Holiday', 'During Holiday', 'After Holiday'
df_cleaned['BeforeHoliday'] = df_cleaned['StateHoliday'].shift(-1).fillna(0)  # Previous day is a holiday
df_cleaned['AfterHoliday'] = df_cleaned['StateHoliday'].shift(1).fillna(0)  # Next day is a holiday
# Out:
# C:\Users\Yibabe\AppData\Local\Temp\ipykernel_10148\2982586206.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['BeforeHoliday'] = df_cleaned['StateHoliday'].shift(-1).fillna(0)  # Previous day is a holiday
# C:\Users\Yibabe\AppData\Local\Temp\ipykernel_10148\2982586206.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['AfterHoliday'] = df_cleaned['StateHoliday'].shift(1).fillna(0)  # Next day is a holiday

# %%
Group by Holiday Periods You can now group your data by these periods (BeforeHoliday, DuringHoliday, AfterHoliday) and calculate the average sales for each period.

# %%
# Create a new column to define the period
df_cleaned['HolidayPeriod'] = 'NormalDay'
df_cleaned.loc[df_cleaned['StateHoliday'] != '0', 'HolidayPeriod'] = 'DuringHoliday'
df_cleaned.loc[df_cleaned['BeforeHoliday'] != '0', 'HolidayPeriod'] = 'BeforeHoliday'
df_cleaned.loc[df_cleaned['AfterHoliday'] != '0', 'HolidayPeriod'] = 'AfterHoliday'
# Out:
# C:\Users\Yibabe\AppData\Local\Temp\ipykernel_10148\2957552132.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['HolidayPeriod'] = 'NormalDay'

# %%
sales_by_period = df_cleaned.groupby('HolidayPeriod')['Sales'].mean()
print(sales_by_period)
# Out:
# HolidayPeriod
# AfterHoliday     4418.307798
# BeforeHoliday    3865.851240
# DuringHoliday     155.109535
# NormalDay        5526.084130
# Name: Sales, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x=sales_by_period.index, y=sales_by_period.values)
plt.title('Average Sales Before, During, and After Holidays')
plt.ylabel('Average Sales')
plt.show()

# %%
# Saving the cleaned DataFrame to the specified path
df_cleaned.to_csv(r'C:\Users\Yibabe\Desktop\10academyAIMweek-4\data\cleaned_merge.csv', index=False)
